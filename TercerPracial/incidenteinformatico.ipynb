# %% [markdown]
# <img src="../img/LogoItq.PNG">

# %% [markdown]
# # 01 PAO25-25 - PYTHON, Data Types

# %% [markdown]
# <img src="../img/PortadaPython.png">

# %% [markdown]
# *Luis Pilaguano*

# %% [markdown]
# <a href="https://colab.research.google.com/drive/1tnOvFNgXiLtktiSsltTr0s308LZSsEPJ">Abre este Jupyter en Google Colab</a>

# %% [markdown]
# # Regresión Lineal: Coste de un incidente de seguridad

# %% [markdown]
# En este ejercicio se explican los fundamentos básicos de la regresión lineal aplicada a un caso de uso sencillo relacionado con la Ciberseguridad.

# %% [markdown]
# ## Enunciado del ejercicio

# %% [markdown]
# El ejercicio consiste en predecir el coste de un incidente de seguridad en base al número de equipos que se han visto afectados. El conjunto de datos es generado de manera aleatoria.

# %% [markdown]
# ### 0. Imports

# %%
# Instalacion de librerías externas
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn

# %% [markdown]
# ### 1. Generación del conjunto de datos

# %%
import numpy as np

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

print("La longitud del conjunto de datos es:", len(X))
# Out:
# La longitud del conjunto de datos es: 100

# %% [markdown]
# ### 2. Visualización del conjunto de datos

# %%
# tu respuesta aqui
import matplotlib.pyplot as plt

plt.scatter(X, y, color='blue')
plt.xlabel("Número de equipos afectados")
plt.ylabel("Coste del incidente")
plt.title("Datos generados - Coste vs Equipos afectados")
plt.show()

# %% [markdown]
# ### 3. Modificación del conjunto de datos

# %%
y = y.ravel()  # convierte y a vector 1D

# %% [markdown]
# ### 4. Construcción del modelo

# %%
#Tu respuesta aqui 
from sklearn.linear_model import LinearRegression
# Crear una instancia del modelo de regresión lineal
modelo = LinearRegression()
# Entrenar (ajustar) el modelo usando los datos X (número de equipos afectados) y y (coste)
modelo.fit(X, y)
# Mostrar el intercepto (b0) de la recta ajustada
print(f"Intercepto (b0): {modelo.intercept_}")
# Mostrar el coeficiente (pendiente b1) que indica cuánto cambia el coste por cada equipo adicional afectado
print(f"Coeficiente (b1): {modelo.coef_[0]}")
# Out:
# Intercepto (b0): 4.1267400224438475
# Coeficiente (b1): 2.9316270924630676

# %% [markdown]
# ### 5. Predicción de nuevos ejemplos

# %%
#Tu respuesta aqui
# Nuevo dato: 1.5 equipos afectados
X_nuevo = np.array([[1.5]])
prediccion = modelo.predict(X_nuevo)
print(f"Predicción del coste para {X_nuevo[0][0]} equipos afectados: {prediccion[0]:.2f}")
# Out:
# Predicción del coste para 1.5 equipos afectados: 8.52

# %% [markdown]
# [Git Hub](https://github.com/HLuiss17/Practicas_Machine_Learning/tree/main/TercerPracial)
